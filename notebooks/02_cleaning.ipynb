# %%
import pandas as pd 
import numpy as np
import warnings 
warnings.filterwarnings("ignore")

df = pd.read_csv(r'C:\Users\Lenovo\Downloads\telco-customer-churn.csv')

df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

print("Missing after conversion:", df['TotalCharges'].isnull().sum())
# Out:
# Missing after conversion: 11

# %%
df[df['TotalCharges'].isnull()][['tenure', 'MonthlyCharges', 'TotalCharges']]
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 488        0           52.55           NaN
# 753        0           20.25           NaN
# 936        0           80.85           NaN
# 1082       0           25.75           NaN
# 1340       0           56.05           NaN
# 3331       0           19.85           NaN
# 3826       0           25.35           NaN
# 4380       0           20.00           NaN
# 5218       0           19.70           NaN
# 6670       0           73.35           NaN
# 6754       0           61.90           NaN

# %%
df['TotalCharges'].fillna(0, inplace=True)
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df.drop('customerID', axis=1, inplace=True)

# %%
print("Duplicates:", df.duplicated().sum())
# Out:
# Duplicates: 22

# %%
df.to_csv('../data/processed/telco_cleaned.csv', index=False)
print("Saved! New shape:", df.shape)
# Out:
# Saved! New shape: (7043, 20)
